# %% [markdown]
# # BigDataViewer in imglyb
#
# Note that this notebook does not run on OSX! You can copy the contents of the relevant cells into a file and run the file through thw `OSWAWTwrapper`:
# ```bash
# WRAPPER="$(python -c 'import site; print( site.getsitepackages()[0] )')/imglyb/OSXAWTwrapper.py"
# python $WRAPPER /path/to/file
# ```
# This example uses, in addition to imglyb, the *h5py* and *scikit-image* packages. You can install them through conda:
# ```bash
# conda install h5py scikit-image
# ```

# %%
import h5py
import math
import numpy as np
import os
import pathlib
import skimage.io
import subprocess
import tempfile
import timeit
import threading
import time

# %% [markdown]
# ## imglyb imports
# An additional *tmp* directory within the classpath will allow us to compile Java code on the fly if we need fast pixel-wise method calls (see example below).

# %%
tmp_dir = tempfile.mkdtemp()

import jnius_config
jnius_config.add_classpath( tmp_dir )

import imglyb
import imglyb.util as util

from jnius import autoclass, PythonJavaClass, java_method, cast

# %% [markdown]
# ## Wait For BDV
# Python is not aware of any Java threads and -- if not run in interactive mode -- would exit even with an active BDV window open. The `bdv_exit_check` as defined below keeps a Python thread alive while BDV is running and prevents Python from exiting. This is not necessary for interactive sessions (e.g. IPython shell, notebook) but is still added for the purpose of demonstration.

# %%
def bdv_exit_check( viewer, run_on_exit = lambda : print( "Exited!" ) ):

    check = autoclass( 'net.imglib2.python.BdvWindowClosedCheck' )()
    frame = cast( 'javax.swing.JFrame', autoclass( 'javax.swing.SwingUtilities' ).getWindowAncestor( viewer ) )
    frame.addWindowListener( check )

    def sleeper():
        while check.isOpen():
            time.sleep( 0.1 )
        run_on_exit()

    t = threading.Thread( target=sleeper )
    t.start()

# %% [markdown]
# ## Multi-Channel vs ARGB

# %%
url = 'http://www.nerdtests.com/mq/testimages/167138_4f49b66c0cb4a87cc906.jpg'
# url = '/home/phil/Pictures/10pm.png'
arr = skimage.io.imread( url )
rai = imglyb.to_imglib( arr )
bdv = util.BdvFunctions.show( rai, 'argb' )
bdv_exit_check( bdv.getBdvHandle().getViewerPanel() )
# Out:
# Exited!

# %%
rai = imglyb.to_imglib( np.transpose( arr, ( 2, 0, 1 ) ) )
bdv = util.BdvFunctions.show( rai, 'argb', util.BdvOptions.options().is2D() )
bdv_exit_check( bdv.getBdvHandle(). getViewerPanel() )
# Out:
# Exited!

# %% [markdown]
# ## Pure Python Converter

# %%
ARGBType = autoclass( 'net.imglib2.type.numeric.ARGBType' )

class CompositeARGBConverter( PythonJavaClass ):
    
    __javainterfaces__ = [ 'net.imglib2.converter.Converter' ]
    
    def __init__( self ):
        super( CompositeARGBConverter, self ).__init__()
        
    @java_method( '(Ljava/lang/Object;Ljava/lang/Object;)V' )
    def convert( self, source, target ):
        target.set( ARGBType.rgba( 
            source.get( 0 ).getInteger(), 
            source.get( 1 ).getInteger(), 
            source.get( 2 ).getInteger(),
            255 ) )
        
       
Converters = autoclass( 'net.imglib2.converter.Converters' )
converter = CompositeARGBConverter()
composite = util.Views.collapseReal( rai )
view = Converters.convert( cast( 'net.imglib2.RandomAccessibleInterval', composite ), converter, ARGBType() )
img = autoclass( 'net.imglib2.img.array.ArrayImgs' ).argbs( view.dimension( 0 ), view.dimension( 1 ) )

start = timeit.default_timer()
util.Helpers.burnIn( view, img )
stop = timeit.default_timer()
print( 'Runtime for converting every pixel:', stop - start )
print( 'Image size:', arr.shape )
# Out:
# Runtime for converting every pixel: 22.912966964002408
# Image size: (282, 330, 3)

# %% [markdown]
# ## Pure Java Converter

# %%
converter_code = """
import net.imglib2.converter.Converter;
import net.imglib2.type.numeric.ARGBType;
import net.imglib2.type.numeric.integer.UnsignedByteType;
import net.imglib2.view.composite.Composite;

public class CompositeARGBTypeConverter< C extends Composite< UnsignedByteType > > implements Converter< C, ARGBType > {
    
    public void convert( C source, ARGBType target ) {
        target.set( ARGBType.rgba( source.get( 0 ).get(), source.get( 1 ).get(), source.get( 2 ).get(), 255 ) );
    }
    
}
"""

fp = pathlib.Path( tmp_dir ) / 'CompositeARGBTypeConverter.java'
print( tmp_dir )
with open( fp, 'w' ) as f:
    f.write( converter_code )

javac = pathlib.Path( os.environ[ 'JAVA_HOME' ] ) / 'bin' / 'javac'
proc = subprocess.run( 
    [ javac, '-cp', jnius_config.split_char.join( jnius_config.get_classpath() ), fp ],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE)
if proc.returncode != 0:
    print ( proc.stderr )
# Out:
# /tmp/tmpq50_n63d

# %%
Converters = autoclass( 'net.imglib2.converter.Converters' )
converter = autoclass( 'CompositeARGBTypeConverter' )()
composite = util.Views.collapseReal( rai )
view = Converters.convert( cast( 'net.imglib2.RandomAccessibleInterval', composite ), converter, ARGBType() )
img = autoclass( 'net.imglib2.img.array.ArrayImgs' ).argbs( view.dimension( 0 ), view.dimension( 1 ) )

start = timeit.default_timer()
util.Helpers.burnIn( view, img )
stop = timeit.default_timer()
print( 'Runtime for converting every pixel:', stop - start )
print( 'Image size:', arr.shape )
# Out:
# Runtime for converting every pixel: 0.022073452000768157
# Image size: (282, 330, 3)

# %%
bdv = util.BdvFunctions.show( view, 'argb', util.BdvOptions.options().is2D() )
bdv_exit_check( bdv.getBdvHandle().getViewerPanel(), lambda : print( 'Different exit message!' ) )
# Out:
# Different exit message!

# %% [markdown]
# ## BDV OverlayRenderer
# `imglyb.util.GenericOverlayRenderer` implements `net.imglib2.ui.OverlayRenderer`. The `GenericOverlayRenderer` constructor accepts two optional arguments, `draw_overlays` and `set_canvas_size`, that implement the respective methods in the `OverlayRenderer` interface. If not specified, these methods will just return without any action. It is also possible to pass stateful functions (see example below).

# %%
# stateless overlay renderer
hello_world_color= autoclass( 'java.awt.Color' ).WHITE
def hello_world( g ):
    g2d = cast( 'java.awt.Graphics2D', g )
    g2d.setColor( hello_world_color )
    g2d.drawString("Hello world!", 30, 130 )
hello_world_overlay = util.GenericOverlayRenderer( hello_world )

# stateful overlay renderer with class that holds state
class RectangleOverlayRenderer:
    def __init__( self ):
        self.w = 0
        self.h = 0
        self.color= autoclass('java.awt.Color').WHITE
        self.stroke = autoclass('java.awt.BasicStroke')( 10 )

    def draw_overlays( self, g ):
        g2d = cast('java.awt.Graphics2D', g)
        g2d.setColor( self.color )
        g2d.setStroke( self.stroke )
        g2d.drawRect( self.w // 2 - self.w // 6, self.h // 2 - self.h // 6, self.w // 3, self.h // 3 )

    def set_canvas_size( self, width, height ):
        print( "Setting canvas size", width, height )
        self.w = width
        self.h = height
    
rectangle_state = RectangleOverlayRenderer()
rectangle_renderer = util.GenericOverlayRenderer( lambda g : rectangle_state.draw_overlays( g ), lambda w, h : rectangle_state.set_canvas_size( w, h ) )

# %% [markdown]
# ## MouseMotionListener
# In analogy to `GenericOverlayRenderer`, `imglyb.util.GenericMouseMotionListener` implements `java.awt.event.MouseMotionListener` with functions `mouse_dragged` and `mouse_moved` that implement the according interface methods and can be passed to the `GenericMouseMotionListener` constructor (default to no-op).

# %%
coordinate_printer = util.GenericMouseMotionListener(
        lambda e : print( "mouse dragged", e.getX(), e.getY() ),
        lambda e : print( "mouse moved", e.getX(), e.getY() )
        )

# %%
random = np.random.randint( 2**32, size=(300,200,100), dtype=np.uint32 )
bdv = util.BdvFunctions.show( imglyb.to_imglib_argb( random ), 'random' )
viewer = bdv.getBdvHandle().getViewerPanel()
viewer.getDisplay().addMouseMotionListener( coordinate_printer )
viewer.getDisplay().addOverlayRenderer( hello_world_overlay )
viewer.getDisplay().addOverlayRenderer( rectangle_renderer )
# Out:
# Setting canvas size 800 579
# mouse moved 799 518
# mouse moved 768 515
# mouse moved 749 513
# mouse moved 727 509
# mouse moved 704 509
# mouse moved 689 509
# mouse moved 672 503
# mouse moved 655 500
# mouse moved 649 498
# mouse moved 644 494
# mouse moved 640 491
# mouse moved 640 492
# mouse moved 639 493
# mouse moved 639 496
# mouse moved 639 498
# mouse moved 639 500
# mouse moved 639 503
# mouse moved 640 504
# mouse moved 641 504
# mouse moved 643 505
# mouse moved 645 507
# mouse moved 647 508
# mouse moved 651 509
# mouse moved 654 510
# mouse moved 660 510
# mouse moved 664 510
# mouse moved 668 510
# mouse moved 670 509
# mouse moved 671 506
# mouse moved 671 503
# mouse moved 671 501
# mouse moved 666 497
# mouse moved 656 494
# mouse moved 647 486
# mouse moved 636 476
# mouse moved 624 472
# mouse moved 607 463
# mouse moved 592 454
# mouse moved 581 446
# mouse moved 573 439
# mouse moved 566 431
# mouse moved 559 424
# mouse moved 556 417
# mouse moved 550 410
# mouse moved 547 404
# mouse moved 544 399
# mouse moved 540 395
# mouse moved 537 389
# mouse moved 534 386
# mouse moved 531 383
# mouse moved 528 381
# mouse moved 525 378
# mouse moved 522 377
# mouse moved 520 376
# mouse moved 516 374
# mouse moved 515 374
# mouse moved 514 374
# mouse moved 512 374
# mouse moved 510 374
# mouse moved 509 374
# mouse moved 508 375
# mouse moved 508 376
# mouse moved 509 376
# mouse moved 513 375
# mouse moved 517 374
# mouse moved 519 370
# mouse moved 522 368
# mouse moved 522 365
# mouse moved 523 363
# mouse moved 523 362
# mouse moved 524 359
# mouse moved 525 357
# mouse moved 525 355
# mouse moved 525 352
# mouse moved 525 349
# mouse moved 525 347
# mouse moved 524 344
# mouse moved 523 343
# mouse moved 520 342
# mouse moved 517 341
# mouse moved 514 340
# mouse moved 512 339
# mouse moved 508 339
# mouse moved 507 339
# mouse moved 506 339
# mouse moved 505 339
# mouse moved 504 339
# Setting canvas size 1177 597
# Setting canvas size 1148 639
# Setting canvas size 1119 679
# Setting canvas size 1088 717
# Setting canvas size 1079 738
# Setting canvas size 1069 752
# Setting canvas size 1056 740
# Setting canvas size 1042 738
# Setting canvas size 743 745
# Setting canvas size 607 736
# Setting canvas size 568 724
# Setting canvas size 535 718
# Setting canvas size 535 705
# Setting canvas size 534 701
# Setting canvas size 419 663
# Setting canvas size 304 617
# Setting canvas size 205 563
# Setting canvas size 176 528
# Setting canvas size 171 504
# Setting canvas size 172 474
# Setting canvas size 214 447
# Setting canvas size 266 432
# Setting canvas size 342 416
# Setting canvas size 378 408
# Setting canvas size 446 403
# Setting canvas size 505 401
# Setting canvas size 549 405
# Setting canvas size 614 417
# Setting canvas size 669 437
# Setting canvas size 734 472
# Setting canvas size 811 519
# Setting canvas size 844 536
# Setting canvas size 837 541
# Setting canvas size 838 541
# Setting canvas size 981 568
# Setting canvas size 1143 586
# Setting canvas size 1211 586
# Setting canvas size 1213 584
# Setting canvas size 1212 583
# Setting canvas size 1208 583
# mouse moved 1170 580
# mouse moved 1130 580
# mouse moved 1080 572
# mouse moved 1026 570
# mouse moved 973 562
# mouse moved 917 553
# mouse moved 875 543
# mouse moved 853 538
# mouse moved 820 520
# mouse moved 798 510
# mouse moved 781 496
# mouse moved 758 477
# mouse moved 740 462
# mouse moved 720 442
# mouse moved 705 427
# mouse moved 688 410
# mouse moved 668 395
# mouse moved 654 381
# mouse moved 640 369
# mouse moved 629 363
# mouse moved 620 356
# mouse moved 611 350
# mouse moved 599 346
# mouse moved 586 344
# mouse moved 578 342
# mouse moved 567 340
# mouse moved 562 340
# mouse moved 558 338
# mouse moved 553 338
# mouse moved 549 337
# mouse moved 548 337
# mouse moved 545 338
# mouse moved 541 340
# mouse moved 540 341
# mouse moved 538 342
# mouse moved 538 343
# mouse moved 537 345
# mouse moved 537 346
# mouse moved 537 347
# mouse moved 538 348
# mouse moved 539 349
# mouse moved 540 351
# mouse moved 543 352
# mouse moved 546 354
# mouse moved 550 356
# mouse moved 554 358
# mouse moved 559 358
# mouse moved 565 360
# mouse dragged 569 362
# mouse dragged 571 362
# mouse dragged 576 363
# mouse dragged 583 364
# mouse dragged 591 364
# mouse dragged 601 364
# mouse dragged 609 364
# mouse dragged 617 364
# mouse dragged 627 364
# mouse dragged 634 364
# mouse dragged 645 364
# mouse dragged 651 363
# mouse dragged 659 363
# mouse dragged 667 363
# mouse dragged 674 361
# mouse dragged 680 360
# mouse dragged 686 357
# mouse dragged 704 345
# mouse dragged 710 340
# mouse dragged 714 337
# mouse dragged 719 335
# mouse dragged 720 331
# mouse dragged 723 328
# mouse dragged 729 320
# mouse dragged 732 316
# mouse dragged 735 312
# mouse dragged 736 309
# mouse dragged 737 305
# mouse dragged 740 299
# mouse dragged 741 295
# mouse dragged 741 292
# mouse dragged 741 288
# mouse dragged 741 285
# mouse dragged 741 282
# mouse dragged 740 280
# mouse dragged 738 279
# mouse dragged 734 278
# mouse dragged 733 278
# mouse dragged 731 278
# mouse dragged 728 278
# mouse dragged 726 278
# mouse dragged 722 278
# mouse dragged 718 280
# mouse dragged 713 281
# mouse dragged 710 283
# mouse dragged 706 286
# mouse dragged 704 287
# mouse dragged 702 288
# mouse dragged 699 292
# mouse dragged 698 294
# mouse dragged 695 299
# mouse dragged 695 302
# mouse dragged 693 303
# mouse dragged 692 309
# mouse dragged 690 312
# mouse dragged 690 316
# mouse dragged 689 319
# mouse dragged 688 323
# mouse dragged 688 327
# mouse dragged 687 330
# mouse dragged 687 332
# mouse dragged 687 334
# mouse dragged 685 335
# mouse dragged 685 338
# mouse dragged 685 340
# mouse dragged 687 341
# mouse dragged 689 342
# mouse dragged 693 343
# mouse dragged 701 345
# mouse dragged 705 346
# mouse dragged 714 349
# mouse dragged 722 350
# mouse dragged 731 350
# mouse dragged 739 350
# mouse dragged 747 350
# mouse dragged 753 350
# mouse dragged 758 349
# mouse dragged 764 347
# mouse dragged 770 344
# mouse dragged 774 343
# mouse dragged 778 342
# mouse dragged 782 340
# mouse dragged 785 339
# mouse dragged 789 336
# mouse dragged 791 335
# mouse dragged 793 332
# mouse dragged 795 330
# mouse dragged 799 329
# mouse dragged 800 326
# mouse dragged 801 324
# mouse dragged 803 320
# mouse dragged 803 317
# mouse dragged 803 312
# mouse dragged 804 303
# mouse dragged 804 299
# mouse dragged 804 297
# mouse dragged 799 294
# mouse dragged 793 290
# mouse dragged 784 287
# mouse dragged 778 284
# mouse dragged 770 281
# mouse dragged 759 279
# mouse dragged 750 278
# mouse dragged 742 274
# mouse dragged 736 273
# mouse dragged 730 271
# mouse dragged 725 270
# mouse dragged 721 270
# mouse dragged 719 270
# mouse dragged 717 270
# mouse dragged 714 270
# mouse dragged 713 271
# mouse dragged 710 272
# mouse dragged 708 275
# mouse dragged 705 277
# mouse dragged 703 281
# mouse dragged 702 282
# mouse dragged 702 287
# mouse dragged 701 292
# mouse dragged 701 294
# mouse dragged 701 297
# mouse dragged 701 299
# mouse dragged 701 302
# mouse dragged 703 304
# mouse dragged 707 307
# mouse dragged 711 309
# mouse dragged 716 312
# mouse dragged 721 314
# mouse dragged 728 316
# mouse dragged 735 317
# mouse dragged 744 320
# mouse dragged 753 320
# mouse dragged 758 321
# mouse dragged 763 323
# mouse dragged 769 323
# mouse dragged 775 324
# mouse dragged 780 324
# mouse dragged 784 324
# mouse dragged 790 324
# mouse dragged 794 324
# mouse dragged 800 324
# mouse dragged 804 326
# mouse dragged 811 326
# mouse dragged 816 326
# mouse dragged 823 324
# mouse dragged 825 324
# mouse dragged 828 324
# mouse dragged 829 324
# mouse dragged 831 324
# mouse dragged 831 323
# mouse dragged 831 320
# mouse dragged 829 318
# mouse dragged 827 315
# mouse dragged 822 312
# mouse dragged 817 310
# mouse dragged 809 306
# mouse dragged 799 300
# mouse dragged 795 297
# mouse dragged 791 296
# mouse dragged 789 294
# mouse dragged 787 293
# mouse dragged 785 293
# mouse dragged 785 292
# mouse dragged 784 292
# mouse dragged 783 292
# mouse dragged 782 291
# mouse dragged 781 291
# mouse dragged 781 290
# mouse dragged 780 290
# mouse dragged 779 289
# mouse dragged 779 289
# mouse dragged 778 289
# mouse dragged 777 289
# mouse dragged 777 289
# mouse dragged 776 290
# mouse dragged 775 290
# mouse dragged 773 290
# mouse dragged 772 291
# mouse dragged 771 291
# mouse dragged 770 291
# mouse dragged 770 290
# mouse dragged 769 290
# mouse dragged 769 290
# mouse dragged 770 290
# mouse dragged 772 290
# mouse dragged 774 290
# mouse dragged 776 290
# mouse dragged 777 290
# mouse dragged 778 290
# mouse dragged 780 290
# mouse dragged 781 290
# mouse dragged 782 290
# mouse dragged 783 290
# mouse dragged 784 290
# mouse dragged 785 290
# mouse dragged 786 290
# mouse dragged 787 290
# mouse dragged 788 290
# mouse dragged 788 289
# mouse moved 788 289
# mouse moved 788 290
# mouse moved 788 291
# mouse moved 788 292
# mouse moved 788 293
# mouse moved 788 294
# mouse moved 788 295
# mouse moved 788 295
# mouse moved 790 295
# mouse moved 792 293
# mouse moved 796 290
# mouse moved 799 289
# mouse moved 800 286
# mouse moved 801 282
# mouse moved 804 278
# mouse moved 805 274
# mouse moved 805 270
# mouse moved 805 264
# mouse moved 806 262
# mouse moved 806 259
# mouse moved 806 258
# mouse moved 806 257
# mouse moved 806 256
# mouse moved 805 255
# mouse dragged 800 258
# mouse dragged 797 260
# mouse dragged 792 261
# mouse dragged 788 264
# mouse dragged 784 264
# mouse dragged 782 265
# mouse dragged 778 265
# mouse dragged 776 265
# mouse dragged 771 264
# mouse dragged 764 263
# mouse dragged 756 260
# mouse dragged 747 259
# mouse dragged 738 256
# mouse dragged 728 255
# mouse dragged 720 252
# mouse dragged 712 252
# mouse dragged 705 251
# mouse dragged 700 251
# mouse dragged 697 251
# mouse dragged 695 251
# mouse dragged 692 251
# mouse dragged 689 252
# mouse dragged 688 253
# mouse dragged 683 255
# mouse dragged 681 257
# mouse dragged 678 260
# mouse dragged 674 263
# mouse dragged 674 264
# mouse dragged 674 265
# mouse dragged 673 265
# mouse dragged 673 266
# mouse dragged 674 266
# mouse dragged 676 266
# mouse dragged 678 267
# mouse dragged 679 267
# mouse dragged 682 267
# mouse dragged 684 267
# mouse dragged 686 267
# mouse dragged 689 267
# mouse dragged 690 267
# mouse dragged 692 267
# mouse dragged 694 266
# mouse dragged 696 266
# mouse dragged 699 266
# mouse dragged 703 265
# mouse dragged 706 264
# mouse dragged 712 264
# mouse dragged 716 263
# mouse dragged 720 263
# mouse dragged 722 262
# mouse dragged 723 262
# mouse dragged 724 261
# mouse dragged 725 261
# mouse dragged 725 260
# mouse dragged 726 259
# mouse dragged 726 258
# mouse dragged 726 257
# mouse dragged 726 256
# mouse dragged 723 254
# mouse dragged 721 252
# mouse dragged 717 251
# mouse dragged 715 250
# mouse dragged 709 250
# mouse dragged 704 250
# mouse dragged 698 250
# mouse dragged 691 251
# mouse dragged 686 251
# mouse dragged 680 251
# mouse dragged 676 252
# mouse dragged 674 252
# mouse dragged 672 252
# mouse dragged 674 252
# mouse dragged 676 251
# mouse dragged 680 250
# mouse dragged 682 249
# mouse dragged 683 249
# mouse dragged 683 250
# mouse dragged 683 250
# mouse dragged 684 251
# mouse dragged 688 251
# mouse dragged 692 252
# mouse dragged 696 253
# mouse dragged 700 253
# mouse dragged 705 253
# mouse dragged 709 253
# mouse dragged 712 251
# mouse dragged 714 250
# mouse dragged 715 249
# mouse dragged 716 248
# mouse dragged 717 247
# mouse dragged 718 247
# mouse dragged 721 247
# mouse dragged 724 248
# mouse dragged 725 249
# mouse dragged 726 250
# mouse dragged 727 251
# mouse dragged 728 252
# mouse dragged 729 253
# mouse dragged 730 253
# mouse dragged 731 253
# mouse dragged 733 253
# mouse dragged 737 252
# mouse dragged 741 251
# mouse dragged 746 250
# mouse dragged 751mouse dragged  249755
#  248
# mouse dragged 758 248
# mouse dragged 759 247
# mouse dragged 761 246
# mouse dragged 764 246
# mouse dragged 766 246
# mouse dragged 767 246
# mouse dragged 769 247
# mouse dragged 773 248
# mouse dragged 776 249
# mouse dragged 777 250
# mouse dragged 779 251
# mouse dragged 780 251
# mouse dragged 780 252
# mouse dragged 780 251
# mouse dragged 779 251
# mouse dragged 778 251
# mouse dragged 777 251
# mouse dragged 774 252
# mouse dragged 770 252
# mouse dragged 765 253
# mouse dragged 760 253
# mouse dragged 752 254
# mouse moved 747 255
# mouse moved 741 255
# mouse moved 738 255
# mouse moved 734 256
# mouse moved 729 257
# mouse moved 726 259
# mouse moved 722 260
# mouse moved 720 261
# mouse moved 718 261
# mouse moved 717 262
# mouse moved 716 264
# mouse moved 716 265
# mouse moved 716 266
# mouse moved 715 266
# mouse moved 715 267
# mouse moved 714 268
# mouse moved 714 269
# mouse moved 714 270
# mouse moved 714 271
# mouse moved 714 272
# mouse moved 714 272
# mouse moved 714 273
# mouse moved 714 274
# mouse moved 714 275
# mouse moved 715 275
# mouse moved 716 275
# mouse moved 717 275
# mouse moved 717 275
# mouse moved 717 276
# mouse moved 717 276
# mouse moved 717 277
# mouse moved 717 278
# mouse moved 717 278
# mouse moved 717 279
# mouse dragged 713 278
# mouse dragged 711 277
# mouse dragged 705 277
# mouse dragged 698 277
# mouse dragged 689 277
# mouse dragged 680 277
# mouse dragged 669 277
# mouse dragged 661 277
# mouse dragged 651 278
# mouse dragged 641 278
# mouse dragged 635 280
# mouse dragged 631 281
# mouse dragged 628 283
# mouse dragged 627 284
# mouse dragged 625 284
# mouse dragged 624 284
# mouse dragged 624 285
# mouse dragged 623 286
# mouse dragged 623 287
# mouse dragged 623 288
# mouse dragged 623 289
# mouse dragged 623 290
# mouse dragged 624 291
# mouse dragged 626 292
# mouse dragged 628 293
# mouse dragged 630 294
# mouse dragged 632 294
# mouse dragged 635 295
# mouse dragged 637 296
# mouse dragged 643 298
# mouse dragged 646 299
# mouse dragged 647 300
# mouse dragged 648 300
# mouse dragged 649 302
# mouse dragged 650 302
# mouse dragged 650 303
# mouse dragged 651 303
# mouse dragged 652 302
# mouse dragged 652 302
# mouse dragged 654 301
# mouse dragged 656 301
# mouse dragged 659 300
# mouse dragged 662 300
# mouse dragged 663 300
# mouse dragged 664 300
# mouse dragged 664 299
# mouse dragged 665 299
# mouse dragged 665 299
# mouse dragged 666 299
# mouse dragged 666 298
# mouse dragged 667 298
# mouse dragged 668 297
# mouse dragged 668 297
# mouse dragged 669 297
# mouse dragged 669 296
# mouse dragged 669 296
# mouse dragged 670 295
# mouse dragged 670 294
# mouse dragged 670 294
# mouse dragged 672 294
# mouse dragged 674 293
# mouse dragged 675 293
# mouse dragged 676 293
# mouse dragged 677 292
# mouse dragged 677 291
# mouse dragged 677 290
# mouse dragged 678 289
# mouse dragged 678 287
# mouse dragged 678 286
# mouse dragged 678 285
# mouse dragged 679 284
# mouse dragged 679 282
# mouse dragged 679 281
# mouse dragged 679 280
# mouse dragged 679 278
# mouse dragged 679 276
# mouse dragged 679 275
# mouse dragged 679 274
# mouse dragged 679 272
# mouse dragged 679 271
# mouse dragged 680 270
# mouse dragged 680 268
# mouse dragged 680 266
# mouse dragged 681 264
# mouse dragged 682 262
# mouse dragged 682 261
# mouse dragged 682 259
# mouse dragged 683 256
# mouse dragged 683 254
# mouse dragged 683 253
# mouse dragged 683 251
# mouse dragged 683 250
# mouse dragged 683 249
# mouse dragged 683 248
# mouse dragged 683 247
# mouse dragged 684 246
# mouse dragged 684 248
# mouse dragged 683 250
# mouse dragged 682 252
# mouse dragged 681 256
# mouse dragged 681 258
# mouse dragged 681 261
# mouse dragged 681 262
# mouse dragged 681 263
# mouse dragged 684 263
# mouse dragged 690 263
# mouse dragged 696 262
# mouse dragged 698 260
# mouse dragged 700 259
# mouse dragged 701 258
# mouse dragged 702 257
# mouse dragged 702 256
# mouse dragged 702 257
# mouse dragged 702 258
# mouse dragged 702 259
# mouse dragged 702 260
# mouse dragged 702 261
# mouse dragged 702 262
# mouse dragged 702 263
# mouse moved 702 264
# mouse moved 701 264
# mouse moved 701 266
# mouse moved 700 267
# mouse moved 700 269
# mouse moved 700 270
# mouse moved 700 272
# mouse moved 700 274
# mouse moved 700 276
# mouse moved 700 277
# mouse moved 700 279
# mouse moved 699 280
# mouse dragged 688 276
# mouse dragged 681 276
# mouse dragged 667 275
# mouse dragged 658 275
# mouse dragged 643 273
# mouse dragged 627 271
# mouse dragged 612 269
# mouse dragged 599 269
# mouse dragged 588 267
# mouse dragged 577 267
# mouse dragged 572 267
# mouse dragged 567 267
# mouse dragged 564 267
# mouse dragged 561 267
# mouse dragged 559 267
# mouse dragged 558 269
# mouse dragged 556 269
# mouse dragged 556 270
# mouse dragged 555 270
# mouse dragged 555 271
# mouse dragged 555 272
# mouse dragged 555 271
# mouse dragged 555 271
# mouse dragged 556 270
# mouse dragged 558 269
# mouse dragged 558 268
# mouse dragged 559 266
# mouse dragged 560 264
# mouse dragged 562 262
# mouse dragged 564 261
# mouse dragged 565 259
# mouse dragged 566 256
# mouse dragged 567 255
# mouse dragged 568 253
# mouse dragged 568 252
# mouse dragged 569 251
# mouse dragged 570 251
# mouse dragged 571 251
# mouse dragged 572 252
# mouse dragged 573 252
# mouse dragged 576 252
# mouse dragged 577 253
# mouse moved 579 254
# mouse moved 584 256
# mouse moved 587 258
# mouse moved 591 259
# mouse moved 595 260
# mouse moved 600 261
# mouse moved 604 261
# mouse moved 611 262
# mouse moved 618 262
# mouse moved 625 262
# mouse moved 639 260
# mouse moved 658 257
# mouse moved 686 250
# mouse moved 710 246
# mouse moved 733 237
# mouse moved 759 230
# mouse moved 791 220
# mouse moved 818 209
# mouse moved 840 203
# mouse moved 860 194
# mouse moved 874 185
# mouse moved 888 180
# mouse moved 895 178
# mouse moved 902 178
# mouse moved 906 178
# mouse moved 908 178
# mouse moved 910 180
# mouse moved 913 183
# mouse moved 914 184
# mouse moved 912 183
# mouse moved 908 183
# mouse moved 904 181
# mouse moved 898 179
# mouse moved 897 176
# mouse moved 895 174
# mouse moved 894 170
# mouse moved 891 168
# mouse moved 889 163
# mouse moved 884 161
# mouse moved 880 158
# mouse moved 875 156
# mouse moved 868 156
# mouse moved 856 156
# mouse moved 850 154
# mouse moved 844 154
# mouse moved 841 154
# mouse moved 840 159
# mouse moved 839 162
# mouse moved 835 165
# mouse moved 831 169
# mouse moved 823 177
# mouse moved 810 185
# mouse moved 797 193
# mouse moved 778 203
# mouse moved 763 211
# mouse moved 745 218
# mouse moved 732 227
# mouse moved 715 235
# mouse moved 706 244
# mouse moved 698 248
# mouse moved 693 250
# mouse moved 687 255
# mouse moved 684 257
# mouse moved 680 259
# mouse moved 673 260
# mouse moved 666 262
# mouse moved 657 262
# mouse moved 653 262
# mouse moved 648 262
# mouse moved 642 262
# mouse moved 636 262
# mouse moved 633 262
# mouse moved 629 261
# mouse moved 627 261
# mouse moved 624 261
# mouse moved 623 261
# mouse moved 622 261
# mouse moved 621 261
# mouse moved 620 262
# mouse moved 619 262
# mouse moved 617 263
# mouse moved 616 263
# mouse moved 616 264
# mouse moved 617 264
# mouse moved 619 264
# mouse moved 620 263
# mouse moved 624 260
# mouse moved 628 255
# mouse moved 631 251
# mouse moved 631 249
# mouse moved 631 248
# mouse dragged 636 247
# mouse dragged 638 246
# mouse dragged 640 245
# mouse dragged 641 245
# mouse dragged 645 245
# mouse dragged 648 244
# mouse dragged 650 244
# mouse dragged 651 244
# mouse dragged 652 244
# mouse dragged 653 244
# mouse dragged 654 244
# mouse dragged 654 245
# mouse dragged 653 246
# mouse dragged 652 247
# mouse dragged 652 248
# mouse dragged 652 249
# mouse dragged 652 251
# mouse dragged 652 252
# mouse dragged 652 253
# mouse dragged 651 253
# mouse dragged 651 254
# mouse dragged 651 255
# mouse dragged 651 256
# mouse dragged 651 257
# mouse dragged 651 258
# mouse dragged 652 260
# mouse dragged 652 261
# mouse dragged 653 262
# mouse dragged 654 263
# mouse dragged 654 264
# mouse dragged 655 264
# mouse dragged 655 265
# mouse dragged 656 266
# mouse dragged 657 268
# mouse dragged 657 270
# mouse dragged 657 272
# mouse dragged 657 275
# mouse dragged 657 277
# mouse dragged 657 281
# mouse dragged 657 284
# mouse dragged 657 287
# mouse dragged 656 289
# mouse dragged 656 291
# mouse dragged 656 292
# mouse dragged 655 295
# mouse dragged 654 296
# mouse dragged 653 298
# mouse dragged 652 300
# mouse dragged 650 303
# mouse dragged 648 304
# mouse dragged 647 306
# mouse dragged 643 308
# mouse dragged 640 309
# mouse dragged 637 309
# mouse dragged 634 310
# mouse dragged 631 312
# mouse dragged 630 312
# mouse dragged 629 312
# mouse dragged 627 312
# mouse dragged 626 312
# mouse dragged 625 312
# mouse dragged 624 312
# mouse dragged 623 312
# mouse dragged 622 312
# mouse dragged 621 312
# mouse dragged 620 312
# mouse dragged 619 312
# mouse dragged 618 311
# mouse dragged 617 310
# mouse dragged 615 310
# mouse dragged 613 306
# mouse dragged 611 302
# mouse dragged 609 297
# mouse dragged 607 292
# mouse dragged 604 285
# mouse dragged 601 280
# mouse dragged 599 274
# mouse dragged 597 270
# mouse dragged 595 266
# mouse dragged 593 262
# mouse dragged 592 261
# mouse dragged 591 260
# mouse dragged 591 258
# mouse dragged 588 256
# mouse dragged 588 255
# mouse dragged 588 251
# mouse dragged 587 249
# mouse dragged 587 248
# mouse dragged 587 246
# mouse dragged 587 245
# mouse dragged 587 243
# mouse dragged 587 242
# mouse dragged 587 241
# mouse dragged 587 239
# mouse dragged 587 238
# mouse dragged 587 236
# mouse dragged 587 235
# mouse dragged 587 234
# mouse dragged 588 233
# mouse dragged 588 232
# mouse dragged 588 231
# mouse moved 589 231
# mouse moved 591 229
# mouse moved 595 229
# mouse moved 602 229
# mouse moved 613 229
# mouse moved 631 227
# mouse moved 652 225
# mouse moved 675 225
# mouse moved 699 225
# mouse moved 723 225
# mouse moved 745 227
# mouse moved 772 227
# mouse moved 800 227
# mouse moved 826 227
# mouse moved 848 227
# mouse moved 861 227
# mouse moved 876 227
# mouse moved 893 232
# mouse moved 904 232
# mouse moved 917 232
# mouse moved 924 232
# mouse moved 928 232
# mouse moved 930 232
# mouse moved 932 229
# mouse moved 937 225
# mouse moved 943 222
# mouse moved 948 216
# mouse moved 956 210
# mouse moved 969 203
# mouse moved 983 191
# mouse moved 992 183
# mouse moved 1002 177
# mouse moved 1012 170
# mouse moved 1018 166
# mouse moved 1021 160
# mouse moved 1022 157
# mouse moved 1022 153
# mouse moved 1022 152
# mouse moved 1022 151
# mouse moved 1025 150
# mouse moved 1030 145
# mouse moved 1034 141
# mouse moved 1038 137
# mouse moved 1043 132
# mouse moved 1047 128
# mouse moved 1050 125
# mouse moved 1053 120
# mouse moved 1055 116
# mouse moved 1057 112
# mouse moved 1058 110
# mouse moved 1060 106
# mouse moved 1060 103
# mouse moved 1060 100
# mouse moved 1060 99
# mouse moved 1061 99
# mouse moved 1061 99
# mouse moved 1062 98
# mouse moved 1063 98
# mouse moved 1063 97
# mouse moved 1063 97
# mouse moved 1063 96
# mouse moved 1063 96
# mouse moved 1064 95
# mouse moved 1065 95
# mouse moved 1065 95
# mouse moved 1066 94
# mouse moved 1067 93
# mouse moved 1067 92
# mouse moved 1068 92
# mouse moved 1070 91
# mouse moved 1074 90
# mouse moved 1077 88
# mouse moved 1083 88
# mouse moved 1089 86
# mouse moved 1096 86
# mouse moved 1103 84
# mouse moved 1107 82
# mouse moved 1111 81
# mouse moved 1115 81
# mouse moved 1119 78
# mouse moved 1120 78
# mouse moved 1121 77
# mouse moved 1123 76
# mouse moved 1124 75
# mouse moved 1124 74
# mouse moved 1124 73
# mouse moved 1124 73
# mouse moved 1123 73
# mouse moved 1123 74
# mouse moved 1123 75
# mouse moved 1122 75
# mouse moved 1122 76
# mouse moved 1122 77
# mouse moved 1121 77
# mouse moved 1121 78
# mouse moved 1121 79
# mouse moved 1121 79
# mouse moved 1120 79
# mouse moved 1120 80
# mouse moved 1119 81
# mouse moved 1119 82
# mouse moved 1119 82
# mouse moved 1119 83
# mouse moved 1119 84
# mouse moved 1119 85
# mouse moved 1119 85
# mouse moved 1118 86
# mouse moved 1118 87
# mouse moved 1118 87
# mouse moved 1118 88
# mouse moved 1118 89
# mouse moved 1118 89
# mouse moved 1118 90
# mouse moved 1118 90
# mouse moved 1118 90
# mouse moved 1118 90
# mouse moved 1118 91
# mouse moved 1117 91
# mouse moved 1117 92
# mouse moved 1116 93
# mouse moved 1116 94
# mouse moved 1115 94
# mouse moved 1115 95
# mouse moved 1115 96
# mouse moved 1115 95
# mouse moved 1115 94
# mouse moved 1115 93
# mouse moved 1115 92
# mouse moved 1115 91
# mouse moved 1115 92
# mouse moved 1115 93
# mouse moved 1115 94
# mouse moved 1115 95
# mouse moved 1115 96
# mouse moved 1114 96
# mouse moved 1114 95
# mouse moved 1114 94
# mouse moved 1114 88
# mouse moved 1115 82
# mouse moved 1117 79
# mouse moved 1117 76
# mouse moved 1119 70
# mouse moved 1121 61
# mouse moved 1122 52
# mouse moved 1124 42
# mouse moved 1125 35
# mouse moved 1127 25
# mouse moved 1127 17
# mouse moved 1128 10
# mouse moved 1129 6
# mouse moved 1129 4
# mouse moved 1129 3
# mouse moved 1133 1

# %%
RealPoint = autoclass( 'net.imglib2.RealPoint' )

class Painter( PythonJavaClass ):
    __javainterfaces__ = ['org/scijava/ui/behaviour/DragBehaviour']


    def __init__( self, img, mask, viewer, paint_listener = lambda : None ):
        super( Painter, self ).__init__()
        self.img = img
        self.mask = mask
        self.radius = int( mask.shape[0] / 2 )
        self.viewer = viewer
        self.oX = 0
        self.oY = 0
        self.n_dim = len( img.shape )
        self.labelLocation = RealPoint( 3 )
        self.lower = np.empty( ( self.n_dim, ), dtype=np.int32 )
        self.upper = np.empty( ( self.n_dim, ), dtype=np.int32 )
        self.paint_listener = paint_listener

    @java_method('(II)V')
    def init( self, x, y ):
        self._paint( x, y )
        self.oX = x
        self.oY = y
        self.viewer.requestRepaint()

    @java_method('(II)V')
    def drag( self, x, y ):
        self._setCoordinates( self.oX, self.oY )
        n_dim = self.labelLocation.numDimensions()
        origin = np.array( [ self.labelLocation.getDoublePosition( d ) for d in range( n_dim ) ] )
        origin_p = RealPoint( n_dim )
        for d, p in enumerate( origin ):
            origin_p.setPosition( p, d )
        self._setCoordinates( x, y )
        target = np.array( [ self.labelLocation.getDoublePosition( d ) for d in range( n_dim ) ] )
        diff = target - origin
        length = np.linalg.norm( diff )
        direction = diff / length
        try:
            for l in range( 1, math.ceil( length ) ):
                for d, dist in enumerate( direction ):
                    origin_p.move( dist, d )
                self._paint_at_localizable( origin_p )
        except Exception as e:
            print( e )
            raise e

        self.oX = x
        self.oY = y
        self.viewer.requestRepaint()

    @java_method('(II)V')
    def end( self, x, y ):
        self.paint_listener()

    def _paint( self, x, y ):
        self._setCoordinates( x, y )
        self._paint_at_localizable( self.labelLocation )

    def _paint_at_localizable( self, labelLocation ):
        for d in range( self.n_dim ):
            int_pos = int( round( labelLocation.getDoublePosition( d ) ) )
            if int_pos < 0 or int_pos >= self.img.shape[ ::-1 ][ d ]:
                return
            self.lower[ d ] = int_pos - self.radius
            self.upper[ d ] = int_pos + self.radius
            
        self.lower = self.lower[::-1]
        self.upper = self.upper[::-1]

        img_lower = np.maximum( self.lower, 0 )
        img_upper = np.minimum( self.upper, self.img.shape )
        
        if np.any( img_lower >= img_upper ):
            return

        mask_lower = np.abs( np.minimum( self.lower, 0 ) ).astype( self.lower.dtype )
        mask_upper = np.minimum( mask_lower + ( img_upper - img_lower ), mask_lower + np.array( self.mask.shape ) )
        img_selection = tuple( slice(l, u) for l, u in zip( img_lower, img_upper ) )
        mask_selection = tuple( slice(l, u) for l, u in zip( mask_lower, mask_upper ) )

        # color_channels = tuple( 255 << ( ( idx * 8 ) if np.random.rand() > 0.5 else 0 ) for idx in range( self.n_dim )  )
        color_channels = tuple( np.random.randint( 128, 255 ) << ( idx * 8 ) for idx in range( self.n_dim )  )
        color = 0
        for c in color_channels:
            color = color | c
        try:
            self.img[ img_selection  ][ self.mask[ mask_selection ] ] = color
        except Exception as e:
            print( "EXCEPTION", e )
            raise e

    def _setCoordinates( self, x, y ):
        self.labelLocation.setPosition( x, 0 )
        self.labelLocation.setPosition( y, 1 )
        self.labelLocation.setPosition( 0, 2 )
        self.viewer.displayToGlobalCoordinates( self.labelLocation )

initial_img = np.zeros( ( 300, 200, 100 ), dtype=np.uint32 ) + ( 80 | ( 80 << 8 ) )
initial_rai = imglyb.to_imglib_argb( initial_img )
bdv = util.BdvFunctions.show( initial_rai, 'canvas' )
mask = np.ones( ( 10, 10, 10 ) ) == 1
painter = Painter( initial_img, mask, bdv.getBdvHandle().getViewerPanel() )

print( initial_img.shape, [ initial_rai.dimension( d ) for d in range( initial_rai.numDimensions() ) ] )

behaviors = util.Helpers.behaviours()
behaviors.install( bdv.getBdvHandle().getTriggerbindings(), "paint" )
behaviors.behaviour( painter, "paint", "SPACE button1" )
bdv_exit_check( bdv.getBdvHandle().getViewerPanel() )
# Out:
# (300, 200, 100) [100, 200, 300]
# /home/phil/.conda/envs/imglyb/lib/python3.6/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in true_divide
# Exited!

# %%
import h5py
import os
import pathlib
import urllib.request
import shutil

# data from https://emdatasets.com/category/emd-examples/
# Hexagonal Silicon Nitride
url = 'https://cremi.org/static/data/sample_A%2B_20160601.hdf'
path = pathlib.Path( '/tmp/sample_A+.h5' )
if not path.is_file():
    with urllib.request.urlopen( url ) as response, open( path, 'wb' ) as out_file:
        shutil.copyfileobj( response, out_file )
    print( 'successfully downloaded file!' )

with h5py.File( path, 'r' ) as f:
    data = f['volumes/raw'].value
rai = imglyb.to_imglib( data )
bdv = util.BdvFunctions.show( rai, 'rai', util.BdvOptions.options().sourceTransform( 4, 4, 40 ) )
bdv_exit_check( bdv.getBdvHandle().getViewerPanel() )
# Out:
# successfully downloaded file!
# Exited!
